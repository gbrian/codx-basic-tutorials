# %%
import pandas as pd
df = pd.read_csv('./test_data.csv')
df
# Out:
#     seq name/first name/last  age         street       city state    zip  \
# 0     1        May  McDonald   33     Ehuma Park   Genumhuf    FL  20456
# 1     2       Lois   Jenkins   60     Gugku Loop    Hesgori    UT  43491
# 2     3  Charlotte       Roy   26     Dosfum Way     Goatpa    ME  73392
# 3     4      Belle    Norman   25    Nicsi Court   Otacudwa    WA  18142
# 4     5        Mae  Morrison   55    Fereh Grove    Uvuemwo    HI  49429
# ..  ...        ...       ...  ...            ...        ...   ...    ...
# 95   96    Richard    Rhodes   24   Zasdut Court  Kahsussaf    AL  21881
# 96   97      Rhoda    Taylor   42     Likeg Road    Odakiti    AZ  89042
# 97   98     Callie    Morton   48    Mobope Pike  Geccatpuz    NV  13860
# 98   99    Gabriel   Estrada   27     Mozwi Park   Uziwesih    SC  88892
# 99  100   Franklin     Dixon   42  Ruhdam Street   Tosnaehu    LA  88661
#
#       dollar    pick        date
# 0    $480.09  YELLOW  09/21/2004
# ...
